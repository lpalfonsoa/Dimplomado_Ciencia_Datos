# %%
# !pip install matplotlib
# !pip install pyjet
# Out:
# Requirement already satisfied: matplotlib in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (3.6.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from matplotlib) (1.22.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting pyjet
#   Downloading pyjet-1.9.0-cp310-cp310-win_amd64.whl (303 kB)
#      ------------------------------------ 303.2/303.2 kB 180.3 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in c:\users\paolo\anaconda3\envs\diplomado_cienciadatos\lib\site-packages (from pyjet) (1.22.3)
# Installing collected packages: pyjet
# Successfully installed pyjet-1.9.0

# %%
import h5py    
import numpy as np 
import matplotlib.pyplot as plt
from pyjet import cluster,DTYPE_PTEPM
import pandas as pd

# %%
fnew = pd.read_hdf("events_anomalydetection_tiny.h5") #Leyeno archivo
#display(fnew)
events_combined = fnew.T #Sacando transpuesta
print(np.shape(events_combined)) 
#print(events_combined[0][2100])
#display(events_combined)
# Out:
# (2101, 1000)

# %%
#Now, let's cluster some jets!
leadpT = {}
alljets = {}
for mytype in ['background','signal']:
    leadpT[mytype]=[] #Diccionarios
    alljets[mytype]=[]
    for i in range(np.shape(events_combined)[1]):
        if (i%100==0):
            print(mytype,i)
            pass
        issignal = events_combined[i][2100] #Preguntar qué rayos, porque debería salirse
        if (mytype=='background' and issignal):
            continue
        elif (mytype=='signal' and issignal==0):
             continue
                #Llena de ceros. El tamaño lo obtine al mirar: En la fila i, mira cada 3era columna, si el valor guardado es mayor que 0
        pseudojets_input = np.zeros(len([x for x in events_combined[i][::3] if x > 0]), dtype=DTYPE_PTEPM)
        for j in range(700):
            if (events_combined[i][j*3]>0):
                pseudojets_input[j]['pT'] = events_combined[i][j*3]
                pseudojets_input[j]['eta'] = events_combined[i][j*3+1]
                pseudojets_input[j]['phi'] = events_combined[i][j*3+2]
                pass
            pass
        sequence = cluster(pseudojets_input, R=1.0, p=-1)
        jets = sequence.inclusive_jets(ptmin=20)
        leadpT[mytype] += [jets[0].pt]
        alljets[mytype] += [jets]
        pass
# Out:
# background 0
# background 100
# background 200
# background 300
# background 400
# background 500
# background 600
# background 700
# background 800
# background 900
# signal 0
# signal 100
# signal 200
# signal 300
# signal 400
# signal 500
# signal 600
# signal 700
# signal 800
# signal 900

# %%
#Let's make some very simple plots.
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
n,b,p = plt.hist(leadpT['background'], bins=50, facecolor='r', alpha=0.2,label='background')
plt.hist(leadpT['signal'], bins=b, facecolor='b', alpha=0.2,label='signal')
plt.xlabel(r'Leading jet $p_{T}$ [GeV]')
plt.ylabel('Number of events')
plt.legend(loc='upper right')
plt.show()
plt.savefig("leadjetpt.pdf")

# %%
mjj={}
for mytype in ['background','signal']:
    mjj[mytype]=[]
    for k in range(len(alljets[mytype])):
        E = alljets[mytype][k][0].e+alljets[mytype][k][1].e
        px = alljets[mytype][k][0].px+alljets[mytype][k][1].px
        py = alljets[mytype][k][0].py+alljets[mytype][k][1].py
        pz = alljets[mytype][k][0].pz+alljets[mytype][k][1].pz
        mjj[mytype]+=[(E**2-px**2-py**2-pz**2)**0.5]
        pass
    pass

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
n,b,p = plt.hist(mjj['background'], bins=50, facecolor='r', alpha=0.2,label='background')
plt.hist(mjj['signal'], bins=b, facecolor='b', alpha=0.2,label='signal')
plt.xlabel(r'$m_{JJ}$ [GeV]')
plt.ylabel('Number of events')
plt.legend(loc='upper right')
plt.show()
plt.savefig("mjj.pdf")
